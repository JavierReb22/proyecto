# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datasets import load_dataset

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df_ch =df[df['job_country'] == 'Chile'].copy()

# %%
df_ch['job_posted_month'] = df_ch['job_posted_date'].dt.strftime('%B')

df_ch
# Out:
#               job_title_short                                      job_title  \
# 91             Data Scientist                                 Data Scientist
# 133     Senior Data Scientist                          Data Scientist Senior
# 237            Data Scientist                        Data Science Specialist
# 301            Data Scientist                                 Data Scientist
# 304             Data Engineer                        Principal Data Engineer
# ...                       ...                                            ...
# 785621          Data Engineer                                  Data Engineer
# 785637          Data Engineer                                  Data Engineer
# 785644           Data Analyst                                   Data Analyst
# 785698          Data Engineer  Data Engineer, Gerencia Business Intelligence
# 785701          Data Engineer  Data Engineer, Gerencia Business Intelligence
#
#              job_location                                        job_via  \
# 91          Temuco, Chile                                via BeBee Chile
# 133       Santiago, Chile                              via Chiletrabajos
# 237       Santiago, Chile                                via Trabajo.org
# 301       Santiago, Chile                                   via LinkedIn
# 304       Santiago, Chile                                via BeBee Chile
# ...                   ...                                            ...
# 785621    Santiago, Chile  via Trabajo.org - Vacantes De Empleo, Trabajo
# 785637    Santiago, Chile  via Trabajo.org - Vacantes De Empleo, Trabajo
# 785644  Las Condes, Chile  via Trabajo.org - Vacantes De Empleo, Trabajo
# 785698  Las Condes, Chile  via Trabajo.org - Vacantes De Empleo, Trabajo
# 785701    Santiago, Chile  via Trabajo.org - Vacantes De Empleo, Trabajo
#
#        job_schedule_type  job_work_from_home search_location  \
# 91             Full-time               False           Chile
# 133            Full-time               False           Chile
# 237            Full-time               False           Chile
# 301            Full-time               False           Chile
# 304            Full-time               False           Chile
# ...                  ...                 ...             ...
# 785621         Full-time               False           Chile
# 785637         Full-time               False           Chile
# 785644         Full-time               False           Chile
# 785698         Full-time               False           Chile
# 785701         Full-time               False           Chile
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 91     2023-01-06 14:07:40                  False                 False
# 133    2023-07-06 13:28:33                  False                 False
# 237    2023-01-29 13:25:16                  False                 False
# 301    2023-05-17 13:33:57                  False                 False
# 304    2023-03-11 13:26:39                  False                 False
# ...                    ...                    ...                   ...
# 785621 2023-09-24 06:31:57                   True                 False
# 785637 2023-08-09 06:31:57                   True                 False
# 785644 2023-08-20 06:29:50                   True                 False
# 785698 2023-08-09 06:32:00                   True                 False
# 785701 2023-08-09 06:31:57                   True                 False
#
#        job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 91           Chile         NaN              NaN              NaN
# 133          Chile         NaN              NaN              NaN
# 237          Chile         NaN              NaN              NaN
# 301          Chile         NaN              NaN              NaN
# 304          Chile         NaN              NaN              NaN
# ...            ...         ...              ...              ...
# 785621       Chile         NaN              NaN              NaN
# 785637       Chile         NaN              NaN              NaN
# 785644       Chile         NaN              NaN              NaN
# 785698       Chile         NaN              NaN              NaN
# 785701       Chile         NaN              NaN              NaN
#
#                                     company_name  \
# 91                                      Talently
# 133                      Alaya Digital Solutions
# 237                                    BairesDev
# 301     SMU S.A. (Unimarc, M10, Alvi, y Super10)
# 304                           McKinsey & Company
# ...                                          ...
# 785621                   Elite Recruitment Group
# 785637                             Tribal Credit
# 785644                    Worldgroup Careers MWT
# 785698                          Falabella Retail
# 785701                          Falabella Retail
#
#                                                job_skills  \
# 91      ['sql', 'python', 'tensorflow', 'numpy', 'pand...
# 133           ['python', 'sql', 'matlab', 'aws', 'azure']
# 237                                                   NaN
# 301                                                   NaN
# 304     ['python', 'sql', 'scala', 'java', 'databricks...
# ...                                                   ...
# 785621  ['php', 'python', 'sql', 'aws', 'airflow', 'ha...
# 785637  ['python', 'scala', 'mysql', 'snowflake', 'ora...
# 785644    ['sql', 'python', 'r', 'snowflake', 'power bi']
# 785698             ['sql', 'python', 'gcp', 'aws', 'git']
# 785701             ['sql', 'python', 'gcp', 'aws', 'git']
#
#                                           job_type_skills job_posted_month
# 91      {'analyst_tools': ['excel', 'tableau'], 'libra...          January
# 133     {'cloud': ['aws', 'azure'], 'programming': ['p...             July
# 237                                                   NaN          January
# 301                                                   NaN              May
# 304     {'cloud': ['databricks', 'aws', 'gcp', 'azure'...            March
# ...                                                   ...              ...
# 785621  {'cloud': ['aws'], 'libraries': ['airflow', 'h...        September
# 785637  {'cloud': ['snowflake', 'oracle', 'aws', 'azur...           August
# 785644  {'analyst_tools': ['power bi'], 'cloud': ['sno...           August
# 785698  {'cloud': ['gcp', 'aws'], 'other': ['git'], 'p...           August
# 785701  {'cloud': ['gcp', 'aws'], 'other': ['git'], 'p...           August
#
# [8118 rows x 18 columns]

# %%
#Obtener tabla con datos especificos llamando los atributos y ordenandolos por indice
df_ch_pivot = df_ch.pivot_table(index='job_posted_month', columns='job_title_short', aggfunc='size')

# %%
df_ch_pivot.reset_index(inplace=True)
df_ch_pivot['month_no'] = pd.to_datetime(df_ch_pivot['job_posted_month'], format='%B').dt.month

df_ch_pivot
# Out:
# job_title_short job_posted_month  Business Analyst  Cloud Engineer  \
# 0                          April                56              10
# 1                         August                64              40
# 2                       December                64              25
# 3                       February                26               8
# 4                        January                39              11
# 5                           July                74              35
# 6                           June                30               3
# 7                          March                41               8
# 8                            May                38               3
# 9                       November                50              16
# 10                       October                99              29
# 11                     September                70              30
#
# job_title_short  Data Analyst  Data Engineer  Data Scientist  \
# 0                         174            288             269
# 1                         148            207             197
# 2                         131            180             146
# 3                          56             69              79
# 4                          78            119             116
# 5                         182            178             181
# 6                         111            113             103
# 7                          72            128             102
# 8                         110            137             102
# 9                         102            171             159
# 10                        152            236             205
# 11                        127            252             165
#
# job_title_short  Machine Learning Engineer  Senior Data Analyst  \
# 0                                       14                   35
# 1                                       33                   23
# 2                                       22                   15
# 3                                       11                    7
# 4                                       10                   10
# 5                                       36                   28
# 6                                       18                   27
# 7                                       19                   10
# 8                                       13                   12
# 9                                       22                    8
# 10                                      21                   21
# 11                                      14                   16
#
# job_title_short  Senior Data Engineer  Senior Data Scientist  \
# 0                                  56                     51
# 1                                  41                     41
# 2                                  27                     22
# 3                                   8                     14
# 4                                  10                     22
# 5                                  38                     64
# 6                                  12                     38
# 7                                  25                      9
# 8                                  19                     20
# 9                                  28                     33
# 10                                 23                     37
# 11                                 33                     33
#
# job_title_short  Software Engineer  month_no
# 0                               57         4
# 1                               91         8
# 2                               81        12
# 3                               29         2
# 4                               63         1
# 5                              103         7
# 6                               14         6
# 7                               28         3
# 8                               26         5
# 9                               73        11
# 10                             116        10
# 11                              74         9

# %%
df_ch_pivot.sort_values('month_no', inplace=True)
df_ch_pivot.set_index('job_posted_month', inplace=True)
df_ch_pivot.drop(columns='month_no', inplace=True)

# %%
df_ch_pivot
# Out:
# job_title_short   Business Analyst  Cloud Engineer  Data Analyst  \
# job_posted_month
# January                         39              11            78
# February                        26               8            56
# March                           41               8            72
# April                           56              10           174
# May                             38               3           110
# June                            30               3           111
# July                            74              35           182
# August                          64              40           148
# September                       70              30           127
# October                         99              29           152
# November                        50              16           102
# December                        64              25           131
#
# job_title_short   Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_posted_month
# January                     119             116                         10
# February                     69              79                         11
# March                       128             102                         19
# April                       288             269                         14
# May                         137             102                         13
# June                        113             103                         18
# July                        178             181                         36
# August                      207             197                         33
# September                   252             165                         14
# October                     236             205                         21
# November                    171             159                         22
# December                    180             146                         22
#
# job_title_short   Senior Data Analyst  Senior Data Engineer  \
# job_posted_month
# January                            10                    10
# February                            7                     8
# March                              10                    25
# April                              35                    56
# May                                12                    19
# June                               27                    12
# July                               28                    38
# August                             23                    41
# September                          16                    33
# October                            21                    23
# November                            8                    28
# December                           15                    27
#
# job_title_short   Senior Data Scientist  Software Engineer
# job_posted_month
# January                              22                 63
# February                             14                 29
# March                                 9                 28
# April                                51                 57
# May                                  20                 26
# June                                 38                 14
# July                                 64                103
# August                               41                 91
# September                            33                 74
# October                              37                116
# November                             33                 73
# December                             22                 81

# %%
df_ch_pivot.plot(kind='line')
# Out:
# <Axes: xlabel='job_posted_month'>

# %%
#Los 5 trabajos mas populares
top_5 = df_ch['job_title_short'].value_counts().head(5)
top_5 = top_5.index.tolist()

# %%
df_ch_pivot[top_5].plot(kind='line')
plt.title('Publicaciones mensuales de trabajos con data en chile')
plt.xlabel('2025')
plt.ylabel('Cantidad Trabajos')
plt.legend()
plt.show()
